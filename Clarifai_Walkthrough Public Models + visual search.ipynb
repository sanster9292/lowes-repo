# %% [markdown]
# ![clarifai_logo](./images/clarifai_logo.png)

# %% [markdown]
# # Table of Content
#
# ### * [Importing the libraries](#libraries)
#
#
# ### * [What are API keys](#api_keys)
#
#
# ### * [Examples of Working with Public Models](#public_models)
#
# ####                 1.  [General Model](#general_model)
# ####                 2.  [Demographics Workflow](#demographics)
# ####                 2.  [Custom Model Predictions](#custom_model)
#
#
# ### * [Visual Search](#visual_search)
#
# ### * [Calling a Public Detection Model - Apparel Detection ](#apparel-detection)

# %% [markdown]
# <a id ='libraries'></a>
# # Let's start by importing the required libaries

# %%
### Clarifai libraries

from clarifai_grpc.channel.clarifai_channel import ClarifaiChannel
from clarifai_grpc.grpc.api import service_pb2_grpc,service_pb2,resources_pb2
from clarifai_grpc.grpc.api.status import status_code_pb2
import numpy as np

# %%
# Create a stub which will be used to interact with the API 
stub = service_pb2_grpc.V2Stub(ClarifaiChannel.get_grpc_channel())

# %% [markdown]
# <a id = 'api_keys'></a>
# # API Keys
#
# * We interact with the Clarifai API through an API Key which is used to make calls to the API.
#
#
# * We can get an API by signing up for a Clarifai account and then getting an API key by creating an application. You can read about that at this link: https://docs.clarifai.com/clarifai-basics/authentication/app-specific-api-keys
#
#
# * You can use the API key to make calls to the public models whose list can be found at the link below
# https://www.clarifai.com/developers/model-gallery
#
#
# * Once you have generated an API key please copy/paste it in the following declartaion and replace it with *YOUR_API_KEY*

# %%
# Setting up an API connection with an API key
# This is how you authenticate.
metadata = (('authorization', 'Key YOUR_API_KEY'),)

# %% [markdown]
# <a id ='public_models'></a>
# # Public model examples
#
# * We have public models which can be used to answer pressing business related use-cases. In fact, many of our clients use our public models to move their business forward.
#
#
# * The great thing about public models is that they come built-in with powerful insights which you can get up and runnning with minimal effort as a developer.
#
#
# * You can just swap out the model in the calls and make calls to the differernt models. You can get the model ids for each model in their appropriate sections in the Model Gallery or by going to the Model Model in an application on Clarifai's Portal. (https://www.clarifai.com/developers/model-gallery)
#
#
# * For the inputs we will provide for prediction, it needs to either be a publically accessible URL or an image/video/text from your computer. In this Notebook I will use publically accessible URLs but you can find details about how to add images from your local computer here (https://docs.clarifai.com/api-guide/data/create-get-update-delete#add-an-input-using-bytes)

# %% [markdown]
# <a id = 'general_model'></a>
# ## General Model
#
# ### We will be looking at the predictions from the General Model for this image
#
# ![Input image for General Model](https://portal.clarifai.com/cms-assets/20180320225539/general-008.jpg)

# %%
#Input URL : https://portal.clarifai.com/cms-assets/20180320225539/general-008.jpg

request = service_pb2.PostModelOutputsRequest(
    # This is the model ID of a publicly available General model. You may use any other public or custom model ID.
    model_id='aaa03c23b3724a16a56b629203edc62c',
    inputs=[
      resources_pb2.Input(data=resources_pb2.Data(image=resources_pb2.Image(url='https://portal.clarifai.com/cms-assets/20180320225539/general-008.jpg')))
    ])
response = stub.PostModelOutputs(request, metadata=metadata)

if response.status.code != status_code_pb2.SUCCESS:
    raise Exception("Request failed, status code: " + str(response.status.code))
else:
    print('Prediction made successfully')
# Out:
# Prediction made successfully

# %% [markdown]
# **We have made a prediction and now let's take a look at the JSON object returned in the variable *response* to see what the raw response looks like.**

# %%
response
# Out:
# status {
#   code: SUCCESS
#   description: "Ok"
#   req_id: "46bede1b5d230f2f558ca1b99fa72783"
# }
# outputs {
#   id: "e1acd80fda8348f9810457a0d05fcf7a"
#   status {
#     code: SUCCESS
#     description: "Ok"
#   }
#   created_at {
#     seconds: 1655485255
#     nanos: 86103424
#   }
#   model {
#     id: "general-image-recognition"
#     name: "Image Recognition"
#     created_at {
#       seconds: 1457543499
#       nanos: 608845000
#     }
#     app_id: "main"
#     output_info {
#       output_config {
#       }
#       message: "Show output_info with: GET /models/{model_id}/output_info"
#       fields_map {
#         fields {
#           key: "concepts"
#           value {
#             string_value: "softmax"
#           }
#         }
#       }
#     }
#     model_version {
#       id: "aa7f35c01e0642fda5cf400f543e7c40"
#       created_at {
#         seconds: 1520370624
#         nanos: 454834000
#       }
#       status {
#         code: MODEL_TRAINED
#         description: "Model is trained and ready"
#       }
#       visibility {
#         gettable: PUBLIC
#       }
#       app_id: "main"
#       user_id: "clarifai"
#     }
#     user_id: "clarifai"
#     input_info {
#       fields_map {
#         fields {
#           key: "image"
#           value {
#             string_value: "images"
#           }
#         }
#       }
#     }
#     train_info {
#     }
#     model_type_id: "visual-classifier"
#     visibility {
#       gettable: PUBLIC
#     }
#   }
#   input {
#     id: "0c66441a7f034560b8c6dd95c405d53d"
#     data {
#       image {
#         url: "https://portal.clarifai.com/cms-assets/20180320225539/general-008.jpg"
#       }
#     }
#   }
#   data {
#     concepts {
#       id: "ai_8S2Vq3cR"
#       name: "dog"
#       value: 0.9980598092079163
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_mp9KG5QH"
#       name: "grass"
#       value: 0.9807001352310181
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_N6BnC4br"
#       name: "mammal"
#       value: 0.9759776592254639
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_M6pVRDsX"
#       name: "canine"
#       value: 0.9749835133552551
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_4CRlSvbV"
#       name: "cute"
#       value: 0.9683369398117065
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_gPNNX7LT"
#       name: "pet"
#       value: 0.9648712277412415
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_LRzQhTHd"
#       name: "puppy"
#       value: 0.9616338610649109
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_SzsXMB1w"
#       name: "animal"
#       value: 0.9510766267776489
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_786Zr311"
#       name: "no person"
#       value: 0.925605058670044
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_ks3RZ5zc"
#       name: "whelp"
#       value: 0.8912031054496765
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_W1zlPRs1"
#       name: "field"
#       value: 0.8848738670349121
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_wqgGDjK4"
#       name: "fur"
#       value: 0.8703173995018005
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_kMfQ8z5w"
#       name: "retriever"
#       value: 0.8691349625587463
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_TJ9wFfK5"
#       name: "portrait"
#       value: 0.8649042844772339
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_QGHBfsBT"
#       name: "funny"
#       value: 0.8108075261116028
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_xWCNmTbf"
#       name: "adorable"
#       value: 0.7936679124832153
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_HkqZwBbr"
#       name: "little"
#       value: 0.7935739159584045
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_Kf5xhjHH"
#       name: "tongue"
#       value: 0.7792866826057434
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_9k62PDS6"
#       name: "hayfield"
#       value: 0.7635138630867004
#       app_id: "main"
#     }
#     concepts {
#       id: "ai_tDN1jkWB"
#       name: "golden retriever"
#       value: 0.7483333945274353
#       app_id: "main"
#     }
#   }
# }

# %% [markdown]
# **There is a lot of information here. Let's just take a look at the predicted values by running the following block of code**

# %%
for concept in response.outputs[0].data.concepts:
    print('%12s: %.2f' % (concept.name, concept.value))
# Out:
#          dog: 1.00
#        grass: 0.98
#       mammal: 0.98
#       canine: 0.97
#         cute: 0.97
#          pet: 0.96
#        puppy: 0.96
#       animal: 0.95
#    no person: 0.93
#        whelp: 0.89
#        field: 0.88
#          fur: 0.87
#    retriever: 0.87
#     portrait: 0.86
#        funny: 0.81
#     adorable: 0.79
#       little: 0.79
#       tongue: 0.78
#     hayfield: 0.76
# golden retriever: 0.75

# %% [markdown]
# <a id = 'demographics'></a>
# ## Demographics Workflow
#
# * In Clarifai's Platform you can chain together different models in a workflow and get predictions from all of them for an input at once. That is what the Demographics workflow does.
#
#
# * In the demographics workflow we chain together three models
#     1. Age
#     2. Multi-cultural appearence
#     3. Gender appearence
#
#
# * We will send an input for prediction to the Demographics Workflow which will give us predictions for all those models. To do this, we will make a prediction to the Workflow predict endpoint which is same for public as well as custom workflows. You can read more about Workflow predict here (https://docs.clarifai.com/api-guide/workflows/common-workflows/workflow-predict)
#
#
# ### We will be looking at the predictions of the Demographics workflow for this image
#
# ![Image for Demographics workflow](https://images.unsplash.com/photo-1544005313-94ddf0286df2?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=634&q=80)

# %%
demo_response = stub.PostWorkflowResults(
    service_pb2.PostWorkflowResultsRequest(
        workflow_id="Demographics",
        inputs=[
            resources_pb2.Input(
                data=resources_pb2.Data(
                    image=resources_pb2.Image(
                        url="https://images.unsplash.com/photo-1544005313-94ddf0286df2?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=634&q=80"
                    )
                )
            )
        ]
    ),
    metadata=metadata
)
if demo_response.status.code != status_code_pb2.SUCCESS:
    raise Exception("Post workflow results failed, status: " + demo_response.status.description)
else:
    print('Prediction made successfully')
# Out:
# Prediction made successfully

# %% [markdown]
# **Let's take a look at the response object**

# %%
demo_response
# Out:
# status {
#   code: SUCCESS
#   description: "Ok"
#   req_id: "b4a92b2ff3497eb9ac1cb9389e406323"
# }
# workflow {
#   id: "Demographics"
#   app_id: "main"
#   created_at {
#     seconds: 1598622565
#     nanos: 390923000
#   }
#   metadata {
#     fields {
#       key: "icon"
#       value {
#         struct_value {
#           fields {
#             key: "url"
#             value {
#               string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-group-of-people.png"
#             }
#           }
#         }
#       }
#     }
#     fields {
#       key: "presetInputs"
#       value {
#         list_value {
#           values {
#             struct_value {
#               fields {
#                 key: "type"
#                 value {
#                   string_value: "image"
#                 }
#               }
#               fields {
#                 key: "url"
#                 value {
#                   string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-old-black-man.jpg"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "type"
#                 value {
#                   string_value: "image"
#                 }
#               }
#               fields {
#                 key: "url"
#                 value {
#                   string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-young-asian-woman.jpg"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "type"
#                 value {
#                   string_value: "image"
#                 }
#               }
#               fields {
#                 key: "url"
#                 value {
#                   string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-old-latino-man.jpg"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "type"
#                 value {
#                   string_value: "image"
#                 }
#               }
#               fields {
#                 key: "url"
#                 value {
#                   string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-young-man.jpg"
#                 }
#               }
#             }
#           }
#           values {
#             struct_value {
#               fields {
#                 key: "type"
#                 value {
#                   string_value: "image"
#                 }
#               }
#               fields {
#                 key: "url"
#                 value {
#                   string_value: "https://s3.amazonaws.com/samples.clarifai.com/featured-models/workflow-demographics-baby.jpg"
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
#   visibility {
#     gettable: PUBLIC
#   }
#   user_id: "clarifai"
# }
# results {
#   status {
#     code: SUCCESS
#     description: "Ok"
#   }
#   input {
#     id: "d777e5bdf249415fb6d6b029353e82ef"
#     data {
#       image {
#         url: "https://images.unsplash.com/photo-1544005313-94ddf0286df2?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=634&q=80"
#       }
#     }
#   }
#   outputs {
#     id: "1364d28ffa85496d95c08252ee52955e"
#     status {
#       code: SUCCESS
#       description: "Ok"
#     }
#     created_at {
#       seconds: 1655485348
#       nanos: 12597573
#     }
#     model {
#       id: "face-detection"
#       name: "Face"
#       created_at {
#         seconds: 1606323024
#         nanos: 453038000
#       }
#       app_id: "main"
#       output_info {
#         output_config {
#         }
#         message: "Show output_info with: GET /models/{model_id}/output_info"
#         fields_map {
#           fields {
#             key: "regions[...].data.concepts[...].id"
#             value {
#               string_value: "predicted_det_labels"
#             }
#           }
#           fields {
#             key: "regions[...].data.concepts[...].value"
#             value {
#               string_value: "predicted_det_scores"
#             }
#           }
#           fields {
#             key: "regions[...].region_info.bounding_box"
#             value {
#               string_value: "predicted_det_bboxes"
#             }
#           }
#         }
#         params {
#           fields {
#             key: "detection_threshold"
#             value {
#               number_value: 0.9
#             }
#           }
#         }
#       }
#       model_version {
#         id: "45fb9a671625463fa646c3523a3087d5"
#         created_at {
#           seconds: 1614879626
#           nanos: 81729000
#         }
#         status {
#           code: MODEL_TRAINED
#           description: "Model is trained and ready"
#         }
#         visibility {
#           gettable: PUBLIC
#         }
#         app_id: "main"
#         user_id: "clarifai"
#       }
#       display_name: "Face-visual-detector"
#       user_id: "clarifai"
#       input_info {
#         fields_map {
#           fields {
#             key: "image"
#             value {
#               string_value: "images"
#             }
#           }
#         }
#       }
#       train_info {
#       }
#       model_type_id: "visual-detector"
#       visibility {
#         gettable: PUBLIC
#       }
#     }
#   }
#   outputs {
#     id: "8708d98a2c9c4efd917b41ca827dbac9"
#     status {
#       code: SUCCESS
#       description: "Ok"
#     }
#     created_at {
#       seconds: 1655485348
#       nanos: 15869150
#     }
#     model {
#       id: "margin-110-image-crop"
#       name: "margin-110"
#       created_at {
#         seconds: 1590505298
#         nanos: 387731000
#       }
#       app_id: "main"
#       output_info {
#         output_config {
#         }
#         message: "Show output_info with: GET /models/{model_id}/output_info"
#         params {
#           fields {
#             key: "margin"
#             value {
#               number_value: 1.1
#             }
#           }
#         }
#       }
#       model_version {
#         id: "b9987421b40a46649566826ef9325303"
#         created_at {
#           seconds: 1590505298
#           nanos: 387731000
#         }
#         status {
#           code: MODEL_TRAINED
#           description: "Model is trained and ready"
#         }
#         visibility {
#           gettable: PUBLIC
#         }
#         app_id: "main"
#         user_id: "clarifai"
#       }
#       display_name: "margin-110-image-crop"
#       user_id: "clarifai"
#       input_info {
#       }
#       train_info {
#       }
#       model_type_id: "image-crop"
#       visibility {
#         gettable: PUBLIC
#       }
#     }
#   }
#   outputs {
#     id: "dec1bc3ce7f145468fe5eb081b007582"
#     status {
#       code: SUCCESS
#       description: "Ok"
#     }
#     created_at {
#       seconds: 1655485348
#       nanos: 21186730
#     }
#     model {
#       id: "ethnicity-demographics-recognition"
#       name: "appearance-multicultural"
#       created_at {
#         seconds: 1594664970
#         nanos: 251137000
#       }
#       app_id: "main"
#       output_info {
#         output_config {
#         }
#         message: "Show output_info with: GET /models/{model_id}/output_info"
#         fields_map {
#           fields {
#             key: "concepts"
#             value {
#               string_value: "softmax"
#             }
#           }
#         }
#       }
#       model_version {
#         id: "b2897edbda314615856039fb0c489796"
#         created_at {
#           seconds: 1595271252
#           nanos: 737304000
#         }
#         status {
#           code: MODEL_TRAINED
#           description: "Model successfully uploaded and is now ready for inferencing"
#         }
#         visibility {
#           gettable: PUBLIC
#         }
#         app_id: "main"
#         user_id: "clarifai"
#       }
#       user_id: "clarifai"
#       input_info {
#         fields_map {
#           fields {
#             key: "image"
#             value {
#               string_value: "images"
#             }
#           }
#         }
#       }
#       train_info {
#       }
#       model_type_id: "visual-classifier"
#       visibility {
#         gettable: PUBLIC
#       }
#     }
#     data {
#       regions {
#         id: "68c9dafce01e421da63411caf051f3fe"
#         region_info {
#           bounding_box {
#             top_row: 0.1855849325656891
#             left_col: 0.3132922351360321
#             bottom_row: 0.5686137676239014
#             right_col: 0.7086293697357178
#           }
#         }
#         data {
#           concepts {
#             id: "ai_wRdd0JFh"
#             name: "White"
#             value: 0.4822404980659485
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_l7P4N9H3"
#             name: "Latino_Hispanic"
#             value: 0.3599814176559448
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_HQBNrsQF"
#             name: "Middle Eastern"
#             value: 0.12107337266206741
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_wB5DLwCQ"
#             name: "Indian"
#             value: 0.022684024646878242
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_zcm624Hj"
#             name: "Black"
#             value: 0.011500652879476547
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_H3Z5TwPR"
#             name: "East Asian"
#             value: 0.0014364091912284493
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_Z9rhv1Wb"
#             name: "Southeast Asian"
#             value: 0.0010836321162059903
#             app_id: "main"
#           }
#         }
#       }
#     }
#   }
#   outputs {
#     id: "16394537ef39489aa422a1a46e45a04a"
#     status {
#       code: SUCCESS
#       description: "Ok"
#     }
#     created_at {
#       seconds: 1655485348
#       nanos: 25186317
#     }
#     model {
#       id: "gender-demographics-recognition"
#       name: "appearance-gender"
#       created_at {
#         seconds: 1594663171
#         nanos: 633958000
#       }
#       app_id: "main"
#       output_info {
#         output_config {
#         }
#         message: "Show output_info with: GET /models/{model_id}/output_info"
#         fields_map {
#           fields {
#             key: "concepts"
#             value {
#               string_value: "softmax"
#             }
#           }
#         }
#       }
#       model_version {
#         id: "ff83d5baac004aafbe6b372ffa6f8227"
#         created_at {
#           seconds: 1595271929
#           nanos: 698518000
#         }
#         status {
#           code: MODEL_TRAINED
#           description: "Model successfully uploaded and is now ready for inferencing"
#         }
#         visibility {
#           gettable: PUBLIC
#         }
#         app_id: "main"
#         user_id: "clarifai"
#       }
#       user_id: "clarifai"
#       input_info {
#         fields_map {
#           fields {
#             key: "image"
#             value {
#               string_value: "images"
#             }
#           }
#         }
#       }
#       train_info {
#       }
#       model_type_id: "visual-classifier"
#       visibility {
#         gettable: PUBLIC
#       }
#     }
#     data {
#       regions {
#         id: "68c9dafce01e421da63411caf051f3fe"
#         region_info {
#           bounding_box {
#             top_row: 0.1855849325656891
#             left_col: 0.3132922351360321
#             bottom_row: 0.5686137676239014
#             right_col: 0.7086293697357178
#           }
#         }
#         data {
#           concepts {
#             id: "ai_SVmv3PD5"
#             name: "Feminine"
#             value: 0.999984860420227
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_cbW8nSHQ"
#             name: "Masculine"
#             value: 1.519788202131167e-05
#             app_id: "main"
#           }
#         }
#       }
#     }
#   }
#   outputs {
#     id: "131289ebbe8c4f5dbbde04b8f4f44d63"
#     status {
#       code: SUCCESS
#       description: "Ok"
#     }
#     created_at {
#       seconds: 1655485348
#       nanos: 29005296
#     }
#     model {
#       id: "age-demographics-recognition"
#       name: "appearance-age"
#       created_at {
#         seconds: 1594653568
#         nanos: 115015000
#       }
#       app_id: "main"
#       output_info {
#         output_config {
#         }
#         message: "Show output_info with: GET /models/{model_id}/output_info"
#         fields_map {
#           fields {
#             key: "concepts"
#             value {
#               string_value: "softmax"
#             }
#           }
#         }
#       }
#       model_version {
#         id: "fb9f10339ac14e23b8e960e74984401b"
#         created_at {
#           seconds: 1595271576
#           nanos: 517193000
#         }
#         status {
#           code: MODEL_TRAINED
#           description: "Model successfully uploaded and is now ready for inferencing"
#         }
#         visibility {
#           gettable: PUBLIC
#         }
#         app_id: "main"
#         user_id: "clarifai"
#       }
#       user_id: "clarifai"
#       input_info {
#         fields_map {
#           fields {
#             key: "image"
#             value {
#               string_value: "images"
#             }
#           }
#         }
#       }
#       train_info {
#       }
#       model_type_id: "visual-classifier"
#       visibility {
#         gettable: PUBLIC
#       }
#     }
#     data {
#       regions {
#         id: "68c9dafce01e421da63411caf051f3fe"
#         region_info {
#           bounding_box {
#             top_row: 0.1855849325656891
#             left_col: 0.3132922351360321
#             bottom_row: 0.5686137676239014
#             right_col: 0.7086293697357178
#           }
#         }
#         data {
#           concepts {
#             id: "ai_q4X20Gr3"
#             name: "20-29"
#             value: 0.875486433506012
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_mVkkkXl5"
#             name: "10-19"
#             value: 0.06705814599990845
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_mXrVvZH9"
#             name: "30-39"
#             value: 0.05702035501599312
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_gXF2jDsQ"
#             name: "40-49"
#             value: 0.00038432670407928526
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_HZ1FxBbs"
#             name: "3-9"
#             value: 4.9659192882245407e-05
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_j72vvqzX"
#             name: "50-59"
#             value: 1.0291350918123499e-06
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_NsrxQ4g9"
#             name: "0-2"
#             value: 4.3783998648905254e-08
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_thZGSK6k"
#             name: "60-69"
#             value: 2.056828840579783e-08
#             app_id: "main"
#           }
#           concepts {
#             id: "ai_RJ64mhdd"
#             name: "more than 70"
#             value: 3.011515203876769e-10
#             app_id: "main"
#           }
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# **Let's take a look at only the results since this is a lot of information. We will start by looking at the predictions from the multi-cultural appearence model**

# %%
mc_response = demo_response.results[0].outputs[2].data.regions[0].data.concepts # multicultural appearence outputs 

for i in range(len(mc_response)):
    print(mc_response[i].name,':', np.around(mc_response[i].value,4))
# Out:
# White : 0.4822
# Latino_Hispanic : 0.36
# Middle Eastern : 0.1211
# Indian : 0.0227
# Black : 0.0115
# East Asian : 0.0014
# Southeast Asian : 0.0011

# %% [markdown]
# **Let's now take a look at the values being predicted by the gender appearence model.**

# %%
gender_response = demo_response.results[0].outputs[3].data.regions[0].data.concepts
# gender_response

for i in range(len(gender_response)):
    print(gender_response[i].name,':', np.around(gender_response[i].value,4))
# Out:
# Feminine : 1.0
# Masculine : 0.0

# %% [markdown]
# **Let's take a look at the Age Appearence where we get approximate predictions of the input from this model**

# %%
age_appearence = demo_response.results[0].outputs[4].data.regions[0].data.concepts
# age_appearence

for i in range(len(age_appearence)):
    print(age_appearence[i].name,':', np.around(age_appearence[i].value,4))
# Out:
# 20-29 : 0.8755
# 10-19 : 0.0671
# 30-39 : 0.057
# 40-49 : 0.0004
# 3-9 : 0.0
# 50-59 : 0.0
# 0-2 : 0.0
# 60-69 : 0.0
# more than 70 : 0.0

# %% [markdown]
# <a id ='custom_model'></a>
# ## Custom Model predictions
#
# * With Clarifai you can create custom models and train them using our platform and then make predictions to it.
#
# * For Custom model predictions to work, the API key you provide will need to be from the application where the custom model is.
#
#
# ### You can read more about the custom model creation and predictions here
#
# * Via Portal: https://docs.clarifai.com/portal-guide/model/pcustom-model-walkthrough
#
# * Via the API : https://docs.clarifai.com/api-guide/model/custom-model-walkthrough
#
#
# I have a model where I trained it to identify four different kind of vehicles, I will be making predicitons to it to work this code. You will need to put the right API key in the following code block and give it the name of the model you created which is the model id and it should work as well

# %%
# Setting up an API connection with an API key
# The API key needs to be from the application where the model was created. 

metadata = (('authorization', 'Key YOUR_API_KEY'),)

custom_response = stub.PostModelOutputs(
    service_pb2.PostModelOutputsRequest(
        model_id="vehicle-finder", # replace the id here with your model id 
#         version_id="{YOUR_MODEL_VERSION_ID}",  # This is optional. Defaults to the latest model version.
        inputs=[
            resources_pb2.Input(
                data=resources_pb2.Data(
                    image=resources_pb2.Image(
                        url="https://samples.clarifai.com/metro-north.jpg"
                    )
                )
            )
        ]
    ),
    metadata=metadata
)
if custom_response.status.code != status_code_pb2.SUCCESS:
    raise Exception("Post model outputs failed, status: " + custom_response.status.description)
else:
    print('prediction made successfully')
# Out:
# prediction made successfully

# %%
# Since we have one input, one output will exist here.
output = custom_response.outputs[0].data.regions[0].data.concepts

output
# Out:
# [id: "bicycles"
# name: "bicycles"
# value: 0.12244516
# app_id: "vehicle-labeling"
# , id: "buses"
# name: "buses"
# value: 4.7368027e-05
# app_id: "vehicle-labeling"
# , id: "cars"
# name: "cars"
# value: 1.089022e-06
# app_id: "vehicle-labeling"
# , id: "motorcycle"
# name: "motorcycle"
# value: 2.679583e-10
# app_id: "vehicle-labeling"
# ]

# %%
# print the custom predicted values

# %%
for i in range(len(output)):
    print(output[i].name,':', np.around(output[i].value,4))
# Out:
# bicycles : 0.1224
# buses : 0.0
# cars : 0.0
# motorcycle : 0.0

# %% [markdown]
# <a id = 'visual_search'></a>
# ## Visual Search
#
# **What is visual search?**
#
# Visual search is when you search your catalog by visual similarity. Let's say that I run retail company which sells clothes and I would like to introduce a visual similarity funcitonality for my customers. I want them to be able to take images of clothes they like and search within our catalog to find similar clothes which they might like.
#
# Using Clarifai you can easily implement this use-case. You could upload images of your catalog to an app using our **Add Inputs** endpoint in the API which you can read here (https://docs.clarifai.com/api-guide/data/create-get-update-delete#add-inputs). So now when you have to search against your entire catalog you can do it in just 1 API call, by asking for a visual search request.
#
# This would take the image you just submitted and re-index (sort) your entire inputs based on how similar they are to the image you just provided. You could refine this use-case by adding metadata to your iputs when you add them to an application. You could add different things to metadata, such as the product URL to redirect to, name of the product or any number of things. You can add inputs with metadata as shown in this documentation. (https://docs.clarifai.com/api-guide/data/create-get-update-delete#add-inputs-with-custom-metadata)
#
#
# **You would use the code shown in the following docs to make a visual search call**
# (https://docs.clarifai.com/api-guide/search/rank#search-by-image-url)
#
# I have an app where I have images stored for a retail client use-case. I am going to make a visual search request to this app with an image of a pair of glasses I like to see if I can find anything that is similar to what I am looking for. The glasses I am looking for and I want to see what the catalog has that is similar to what i like
#
# ![](https://images-na.ssl-images-amazon.com/images/I/71AIdaQLMmL._AC_UL1500_.jpg)

# %%
# The API key here will be the API key from the app where you have added your inputs to 
metadata = (('authorization', 'Key YOUR_API_KEY'),)

search_response = stub.PostAnnotationsSearches(
    service_pb2.PostAnnotationsSearchesRequest(
        searches = [
            resources_pb2.Search(
                query=resources_pb2.Query(
                    ranks=[
                        resources_pb2.Rank(
                            annotation=resources_pb2.Annotation(
                                data=resources_pb2.Data(
                                    image=resources_pb2.Image(
                                        url="https://images-na.ssl-images-amazon.com/images/I/71AIdaQLMmL._AC_UL1500_.jpg"
                                    )
                                )
                            )
                        )
                    ]
                )
            )
        ]
    ),
    metadata=metadata
)

# %% [markdown]
# ### Let's take a look at the scores returned

# %%
if search_response.status.code != status_code_pb2.SUCCESS:
    raise Exception("Post searches failed, status: " + search_response.status.description)

print("Search result:")
for hit in search_response.hits:
    print("\tScore %.2f for annotation: %s off input: %s" % (hit.score, hit.annotation.id, hit.input.id))
# Out:
# Search result:
# 	Score 0.96 for annotation: a046ca1ead4f4cd98ffcb44797734c46 off input: 1002701328
# 	Score 0.96 for annotation: 9b0faa4c553f463b9922c7a8ef8dcaf3 off input: 1002701312
# 	Score 0.96 for annotation: ee3603df9669402089497812ff91474c off input: 1001853876
# 	Score 0.96 for annotation: 7ebc1decfbf241d4aa20da8592ee3c50 off input: 1001852888
# 	Score 0.96 for annotation: 1ecfee6e930f491aa858529b266af471 off input: 1001863122
# 	Score 0.96 for annotation: 938a35e694094b5f9a2712551fbc5a42 off input: 50223913
# 	Score 0.96 for annotation: 64c74ea40c614c9097c13b670d2b7f6f off input: 1001863570
# 	Score 0.96 for annotation: dc2a2abe161c40668d1f6cedead68d2d off input: 1001854000
# 	Score 0.96 for annotation: c3f379148f834448a2997087cd820b00 off input: 1001853080
# 	Score 0.96 for annotation: 514f298c104641259c2e93ba9f6e8251 off input: 1001853104
# 	Score 0.96 for annotation: b74476dbdf7b45a4b88f24abeda198cc off input: 1000608413
# 	Score 0.96 for annotation: 927598e7a65548418bb080671e47ea9f off input: 1000608407
# 	Score 0.96 for annotation: 3e34c38d051546f796dd097afd0c1a08 off input: 1000608419
# 	Score 0.96 for annotation: 70a36499e11c48bcabb2cef75183c45b off input: 1002438904
# 	Score 0.96 for annotation: 0225a77c3de54a89bc8d01cc74518cc2 off input: 1001852530
# 	Score 0.96 for annotation: e61103c642f7473aacac150271f54852 off input: 1001852552
# 	Score 0.96 for annotation: 6c060629b21747359d9c2866c03e3175 off input: 1001863850
# 	Score 0.96 for annotation: dde1135a5a794aca9472802ca1082966 off input: 1001855010
# 	Score 0.96 for annotation: 40f86461c0cc4b5ca688b01393764d67 off input: 1001854702
# 	Score 0.96 for annotation: dc99724b5d0d4e62803f2c2c7bbab01b off input: 1001854724
# 	Score 0.96 for annotation: da82bc693b1d46aaa09950e9b88c6ed0 off input: 1002438786
# 	Score 0.96 for annotation: bd46fbc20eb14473bab548d88d9d9d6d off input: 1001740266
# 	Score 0.96 for annotation: e0dec18c902f467da3f4ecbfb470fc6e off input: 1001854110
# 	Score 0.96 for annotation: e4e9ba9fe7d948539e7fdddd2e2d0926 off input: 1001854088
# 	Score 0.96 for annotation: baa276390b62497bb1bc79d4ca38f496 off input: 1001853936
# 	Score 0.96 for annotation: 0b2a92561c4747c98e35bf1fd8421966 off input: 1001863150
# 	Score 0.96 for annotation: d0779d6677c04396bd8fc764fd6b4644 off input: 1001863654
# 	Score 0.96 for annotation: 1926175db53947578994cbc20e592f6c off input: 1002701224
# 	Score 0.96 for annotation: 7aefef9d1a5d4d8296db43ad4490677c off input: 1002773806
# 	Score 0.96 for annotation: 824546b48d854fd1ad71e346303254c6 off input: 1002701456
# 	Score 0.96 for annotation: 863ca6d01aa445dcb08020fe8117e4d4 off input: 1002701376
# 	Score 0.96 for annotation: dcce6d7598c24207b946fcdea0f7b907 off input: 1001849152
# 	Score 0.96 for annotation: 4247e88e88de4bff92f918bfd545389f off input: 1002773860
# 	Score 0.96 for annotation: c80dd372024f48fda4a95b3e340c343e off input: 1002773914
# 	Score 0.95 for annotation: bfc1622482b946fca7e27f85d038ab0d off input: 1001740298
# 	Score 0.95 for annotation: 11056578919b4ac8a83a6a42769f35c8 off input: 1001854462
# 	Score 0.95 for annotation: 740356f0f2c3458aba1b093d7165b3c1 off input: 1001854484
# 	Score 0.95 for annotation: 227646c06ac24a28a2b6242ceee6f179 off input: 1001862898
# 	Score 0.95 for annotation: e0b7e75081ae438f8d38addbbef10bb5 off input: 1001862912
# 	Score 0.95 for annotation: 2513c70105894a91b445578fb78e2136 off input: 1001854066
# 	Score 0.95 for annotation: 9ebfae574af2465fa4c5806df00bd9f6 off input: 1002701260
# 	Score 0.95 for annotation: 39e752f413e9464c8281af49aebc4f80 off input: 1001863528
# 	Score 0.95 for annotation: 85d4443ff5014a3c8a80453011cb7d69 off input: 1000518499
# 	Score 0.95 for annotation: 8980e8a7819c421fbc566a16b5224cb3 off input: 1001853978
# 	Score 0.95 for annotation: 7e502ede5ead4903ae7469e86e6ea0a2 off input: 1002701440
# 	Score 0.95 for annotation: 8140424536b048f89d93850f103a6569 off input: 1002701242
# 	Score 0.95 for annotation: af280d33ef2145e5a57f629b3692e5af off input: 1001863752
# 	Score 0.95 for annotation: 9ec7ce71af07487ca4ef293a458edbad off input: 1001863766
# 	Score 0.95 for annotation: d936fef303e04630ad9e0dbb140aa8a3 off input: 1001863276
# 	Score 0.95 for annotation: e0a0f6cb32644320aa7f19147b497e99 off input: 1001863612
# 	Score 0.95 for annotation: 92c01a3c378c4d25b299159171229340 off input: 1002438858
# 	Score 0.95 for annotation: d27b4324b1674e018f0dfd8386830c5a off input: 1001829358
# 	Score 0.95 for annotation: 2d3a07183eae4d3fad9ca82e3e620bdd off input: 1001854856
# 	Score 0.95 for annotation: d8c81f7d85d242e485100a197f687050 off input: 1001863836
# 	Score 0.95 for annotation: 7442d400714e43fba49ad55ab8e36acf off input: 1001854308
# 	Score 0.95 for annotation: fbf51d3e6ae24f478393f3f425357404 off input: 1001854286
# 	Score 0.95 for annotation: efdb0b73cf464203a9247e93910919ec off input: 1001854440
# 	Score 0.95 for annotation: 0dd26c61bfe549db9ecc466420fa9b61 off input: 1001821902
# 	Score 0.95 for annotation: d07fa84306054cdfa31c54edfe9d919b off input: 1002438232
# 	Score 0.95 for annotation: 4a881502a9ec4b8fac741e3ceff9148c off input: 1001822112
# 	Score 0.95 for annotation: a19e1897bb3942afa485d96e8ba4ec76 off input: 1001852218
# 	Score 0.95 for annotation: 0c95456e07e6474da8a9e5225c3cb917 off input: 1001852194
# 	Score 0.95 for annotation: 6fbea288c1e145618e243594aa22c555 off input: 1001863514
# 	Score 0.95 for annotation: e7916c52026f4671962a69e2704ab43a off input: 1001849136
# 	Score 0.95 for annotation: b8d4f970a61f4110b646cabc5e897332 off input: 1002438472
# 	Score 0.95 for annotation: 5409961c04c14920a57fea74b314b453 off input: 1001854330
# 	Score 0.95 for annotation: 18ae709054c443ee96483a4d0af9540c off input: 1002290786
# 	Score 0.95 for annotation: d9de7ae562bb4abe8d3346d15de9d2a8 off input: 1001848960
# 	Score 0.95 for annotation: c4cc210f657f48ea8228b325b579e017 off input: 1001849120
# 	Score 0.95 for annotation: 22bd6bbdfb3a47c8a20ac0a0b2bc0759 off input: 1001854242
# 	Score 0.95 for annotation: 49b5ceb015a94b2892cd783e493dfd99 off input: 1001854044
# 	Score 0.95 for annotation: ab98d411bcd345cab132c48c7a9bf197 off input: 1001828878
# 	Score 0.94 for annotation: 529318ed9487423997a896f481c863bf off input: 1002863122
# 	Score 0.94 for annotation: c2edd849e8314652ba2fa964d0f95cce off input: 1001849072
# 	Score 0.94 for annotation: 41eb7f5498174fafa81e0dbe605cccfe off input: 1001849168
# 	Score 0.94 for annotation: e332f3e03de5445e8058c32cc841deb7 off input: 1000603671
# 	Score 0.94 for annotation: 13cdf2eb69ab4c8aa1b343b4a676e422 off input: 1001822142
# 	Score 0.94 for annotation: 572f0f35007d4287a050eb801b92e69e off input: 1001822382
# 	Score 0.94 for annotation: 95d5f62e526b408790a35fabff2f3f0a off input: 1001853916
# 	Score 0.94 for annotation: 5cb973aa40544f668de52b39985a4ff4 off input: 1001828908
# 	Score 0.94 for annotation: 0ec3cb398396497ba8f3223587eb5311 off input: 1001822202
# 	Score 0.94 for annotation: 5406d1374ea540878fd3197bd240db9c off input: 1002701392
# 	Score 0.94 for annotation: a95c291fbb254774a901d03a455646c3 off input: 1001822352
# 	Score 0.94 for annotation: 0684eaa0e3dc4ec19f554175d1499274 off input: 1001829328
# 	Score 0.94 for annotation: b20cda655a5e494688e54d638f06b941 off input: 1002863090
# 	Score 0.94 for annotation: 254902af8cea460db13440bbde9bbae6 off input: 1001852720
# 	Score 0.94 for annotation: 028cfbace15e46548861f2bc0d28857d off input: 1001853196
# 	Score 0.94 for annotation: 806a6b6ee7714a99b19290f9a675f1b7 off input: 1002290300
# 	Score 0.94 for annotation: ecc5c32ad7bb45a586440ea1db0bbd2b off input: 1001853218
# 	Score 0.94 for annotation: 4575345eedd3499dac0a08c28279bc82 off input: 1001848880
# 	Score 0.94 for annotation: c5eecf2e079949858a1c832d2f189942 off input: 1001849184
# 	Score 0.94 for annotation: 4608f29e75ab4db693972148ae7af4f6 off input: 1001829268
# 	Score 0.94 for annotation: 1965e4f909b643d68c708c975ec69090 off input: 1001849248
# 	Score 0.94 for annotation: 2506810ae42a4e74a18262d224ab74b3 off input: 1001822172
# 	Score 0.94 for annotation: 6a9e7749297e492a949b1bb632c82ed9 off input: 1001853032
# 	Score 0.94 for annotation: e71132b659f642709af2089129a19303 off input: 1002290462
# 	Score 0.94 for annotation: ae6cf30a95854c8eb2a85b643dd1549e off input: 1001849354
# 	Score 0.94 for annotation: 42a353cd24da4e2db1a7defe63cc27e0 off input: 1001829148
# 	Score 0.94 for annotation: 5dbbbff94b0f4cf691198be8234858b9 off input: 1001854022
# 	Score 0.94 for annotation: 819c9e0b33884470a5850fa6bd1b1425 off input: 1001863556
# 	Score 0.94 for annotation: 15b21ade55d846489dc7ef02d9673a7e off input: 1001854548
# 	Score 0.94 for annotation: 75d82c397cee4aaa9bd8528256525b04 off input: 1001849200
# 	Score 0.94 for annotation: 5b59692698da479c8899f81cc5d5f2b4 off input: 1001848896
# 	Score 0.94 for annotation: 5ba58411e4a44e3e81040bcb474f9b1b off input: 1001821842
# 	Score 0.94 for annotation: a8ce581c38a84ca39460f8473e816420 off input: 1001849104
# 	Score 0.94 for annotation: 535392ace46f4caaa2d7fbbd674696ca off input: 1001821872
# 	Score 0.94 for annotation: ff04bb1a5752493e8ec4b4995dee0ff3 off input: 1001822322
# 	Score 0.94 for annotation: f61bd5f16e4e488099c631fc2553cb89 off input: 1001853956
# 	Score 0.94 for annotation: 21a486e0397944c0abc452bc4982d304 off input: 1001853896
# 	Score 0.94 for annotation: a335302a42a64fd084d85fc25a8d4808 off input: 1001822412
# 	Score 0.94 for annotation: 116a9c87a76742778ed0a0f5bf93fef4 off input: 1001859472
# 	Score 0.94 for annotation: b6a5cb9d6d3f45ed8a3b43b965f9a8bc off input: 1001849370
# 	Score 0.94 for annotation: c60a9c8afbab4b6296b656f320586548 off input: 1001849232
# 	Score 0.94 for annotation: 7ea604866d7e4148b68b1e983d090c87 off input: 1000603695
# 	Score 0.94 for annotation: 8716e1307e3d41b68ab69c52b045ea01 off input: 1001828728
# 	Score 0.94 for annotation: e5a5404480c14d81b5cf6a87c0e3f6ee off input: 1001849216
# 	Score 0.94 for annotation: 4e9eb95a1998481e8dddad7febf09a9c off input: 1001829118
# 	Score 0.94 for annotation: 139c9c92f3b44672aa998442836548f1 off input: 1001863542
# 	Score 0.94 for annotation: 13488953de3e435fa81da4de13adb8ef off input: 1001853504
# 	Score 0.94 for annotation: bb6feacc2397408eae479edfef335cc4 off input: 1001853526
# 	Score 0.94 for annotation: 4643ffd4ff0848d79d4e6475d5aeee87 off input: 1001821932
# 	Score 0.94 for annotation: 4d66ea04f0e6450b8fdd0d9e4f90eb33 off input: 1001849402
# 	Score 0.94 for annotation: e77b97bfba294871a3c17b9c68485f0a off input: 1001849322
# 	Score 0.94 for annotation: ac5ede9eee094068a8e8fa753c1b23f3 off input: 1001849024
# 	Score 0.94 for annotation: cda4e6e6a5524217bdbccba484f33bdf off input: 1000039825
# 	Score 0.94 for annotation: 811d8e01296f45979c4f0fec51953b49 off input: 1001828758
# 	Score 0.94 for annotation: 9bcec97fbe3b4f799519a269b1c36980 off input: 1001849088
# 	Score 0.94 for annotation: 5e9de591637c46b69844c581cf825dcc off input: 1001848912

# %% [markdown]
# ### This is interesting and all but let's look at the raw data returned and see if we can come up with more interesting way of using this data.
#
# The following response shows the raw response where the images are being returned with their metadata which we added at the time of upload

# %%
search_response.hits
# Out:
# [score: 0.96423835
# input {
#   id: "1002701328"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/731919/731919860361.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/7461e5b312e231f5541da62f27854bb6"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1002701328"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Magnifeye-Magnifeye-Retro-Black-1-25/1002701328"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Magnifeye Magnifeye Retro Black 1.25"
#         }
#       }
#     }
#     clusters {
#       id: "518_245"
#     }
#   }
#   created_at {
#     seconds: 1599815337
#     nanos: 268322000
#   }
#   modified_at {
#     seconds: 1599891592
#     nanos: 774946000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "a046ca1ead4f4cd98ffcb44797734c46"
#   input_id: "1002701328"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599891588
#     nanos: 250288000
#   }
#   modified_at {
#     seconds: 1599891588
#     nanos: 250288000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.96423835
# input {
#   id: "1002701312"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/731919/731919860200.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/7461e5b312e231f5541da62f27854bb6"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1002701312"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Magnifeye-Magnifeye-Retro-Black-1-5/1002701312"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Magnifeye Magnifeye Retro Black 1.5"
#         }
#       }
#     }
#     clusters {
#       id: "518_245"
#     }
#   }
#   created_at {
#     seconds: 1599815337
#     nanos: 268322000
#   }
#   modified_at {
#     seconds: 1599891592
#     nanos: 774946000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "9b0faa4c553f463b9922c7a8ef8dcaf3"
#   input_id: "1002701312"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599891588
#     nanos: 250284000
#   }
#   modified_at {
#     seconds: 1599891588
#     nanos: 250284000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.962711
# input {
#   id: "1001853876"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001853876.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/d224500cec14947108269a12d123afe5"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001853876"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Kvasir-Plastic-Safety-Glasses/1001853876"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Kvasir Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "ee3603df9669402089497812ff91474c"
#   input_id: "1001853876"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336378000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336378000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.96160436
# input {
#   id: "1001852888"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001852888.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/718ab2694a279eed8fc23aab4b9aa0e2"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001852888"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Thor-Plastic-Anti-Fog-Safety-Glasses/1001852888"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Thor Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822269
#     nanos: 355754000
#   }
#   modified_at {
#     seconds: 1599944163
#     nanos: 290295000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "7ebc1decfbf241d4aa20da8592ee3c50"
#   input_id: "1001852888"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599944160
#     nanos: 357119000
#   }
#   modified_at {
#     seconds: 1599944160
#     nanos: 357119000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.96160436
# input {
#   id: "1001863122"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100186/1001863122.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/718ab2694a279eed8fc23aab4b9aa0e2"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001863122"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Thor-Plastic-Safety-Glasses/1001863122"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Thor Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "1ecfee6e930f491aa858529b266af471"
#   input_id: "1001863122"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336369000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336369000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9610102
# input {
#   id: "50223913"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/811465/811465005635.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/dcdab17ca050b9c6c8e67209c000c6d4"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "50223913"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Panther-Vision-LIGHTSPECS-Vindicator-Plastic-Anti-Fog-Safety-Glasses-Flashlight-Included/50223913"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Panther Vision LIGHTSPECS Vindicator Plastic Anti-Fog Safety Glasses Flashlight Included"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818333
#     nanos: 109767000
#   }
#   modified_at {
#     seconds: 1599927892
#     nanos: 49106000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "938a35e694094b5f9a2712551fbc5a42"
#   input_id: "50223913"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927890
#     nanos: 178695000
#   }
#   modified_at {
#     seconds: 1599927890
#     nanos: 178695000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.96079385
# input {
#   id: "1001863570"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100186/1001863570.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/054cecfb8a17ed9b03e92f9a3a7500df"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001863570"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Njord-Plastic-Safety-Glasses/1001863570"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Njord Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_245"
#     }
#   }
#   created_at {
#     seconds: 1599822271
#     nanos: 118321000
#   }
#   modified_at {
#     seconds: 1599948081
#     nanos: 244007000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "64c74ea40c614c9097c13b670d2b7f6f"
#   input_id: "1001863570"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599948079
#     nanos: 56031000
#   }
#   modified_at {
#     seconds: 1599948079
#     nanos: 56031000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95952445
# input {
#   id: "1001854000"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001854000.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/208e42924bbd0594b827fbcd891b7ab9"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001854000"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Njord-Plastic-Safety-Glasses/1001854000"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Njord Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822268
#     nanos: 549315000
#   }
#   modified_at {
#     seconds: 1599946128
#     nanos: 716569000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "dc2a2abe161c40668d1f6cedead68d2d"
#   input_id: "1001854000"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599946126
#     nanos: 711939000
#   }
#   modified_at {
#     seconds: 1599946126
#     nanos: 711939000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9593208
# input {
#   id: "1001853080"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001853080.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/0178f0ae16e1969b0482f3a901e240f1"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001853080"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Thor-Plastic-Safety-Glasses/1001853080"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Thor Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822269
#     nanos: 355754000
#   }
#   modified_at {
#     seconds: 1599944163
#     nanos: 290295000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "c3f379148f834448a2997087cd820b00"
#   input_id: "1001853080"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599944160
#     nanos: 357124000
#   }
#   modified_at {
#     seconds: 1599944160
#     nanos: 357124000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9593208
# input {
#   id: "1001853104"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001853104.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/0178f0ae16e1969b0482f3a901e240f1"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001853104"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Thor-Plastic-Anti-Fog-Safety-Glasses/1001853104"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Thor Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "514f298c104641259c2e93ba9f6e8251"
#   input_id: "1001853104"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336373000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336373000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95897007
# input {
#   id: "1000608413"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/811465/811465004478.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/a33a3765aa17b84966957d0d63e587bc"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1000608413"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Panther-Vision-LIGHTSPECS-Plastic-Anti-Fog-Safety-Glasses-Flashlight-Included/1000608413"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Panther Vision LIGHTSPECS Plastic Anti-Fog Safety Glasses (Flashlight Included)"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822268
#     nanos: 549315000
#   }
#   modified_at {
#     seconds: 1599946128
#     nanos: 716569000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "b74476dbdf7b45a4b88f24abeda198cc"
#   input_id: "1000608413"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599946126
#     nanos: 711926000
#   }
#   modified_at {
#     seconds: 1599946126
#     nanos: 711926000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95897007
# input {
#   id: "1000608407"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/811465/811465004423.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/a33a3765aa17b84966957d0d63e587bc"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1000608407"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Panther-Vision-LIGHTSPECS-Plastic-Anti-Fog-Safety-Glasses-Flashlight-Included/1000608407"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Panther Vision LIGHTSPECS Plastic Anti-Fog Safety Glasses (Flashlight Included)"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822268
#     nanos: 549315000
#   }
#   modified_at {
#     seconds: 1599946128
#     nanos: 716569000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "927598e7a65548418bb080671e47ea9f"
#   input_id: "1000608407"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599946126
#     nanos: 711942000
#   }
#   modified_at {
#     seconds: 1599946126
#     nanos: 711942000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95897007
# input {
#   id: "1000608419"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/811465/811465004485.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/a33a3765aa17b84966957d0d63e587bc"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1000608419"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Panther-Vision-LIGHTSPECS-Plastic-Anti-Fog-Safety-Glasses-Flashlight-Included/1000608419"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Panther Vision LIGHTSPECS Plastic Anti-Fog Safety Glasses (Flashlight Included)"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818333
#     nanos: 109767000
#   }
#   modified_at {
#     seconds: 1599927892
#     nanos: 49106000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "3e34c38d051546f796dd097afd0c1a08"
#   input_id: "1000608419"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927890
#     nanos: 178701000
#   }
#   modified_at {
#     seconds: 1599927890
#     nanos: 178701000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95818067
# input {
#   id: "1002438904"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/193027/193027064541.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/adca5d2f8b24d6ce564eb784ccb4031c"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1002438904"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/SAS-Safety-Diamondback-Plastic-Anti-Fog-Safety-Glasses/1002438904"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "SAS Safety Diamondback Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818332
#     nanos: 423096000
#   }
#   modified_at {
#     seconds: 1599927863
#     nanos: 569850000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "70a36499e11c48bcabb2cef75183c45b"
#   input_id: "1002438904"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927861
#     nanos: 848953000
#   }
#   modified_at {
#     seconds: 1599927861
#     nanos: 848953000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9577444
# input {
#   id: "1001852530"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001852530.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/2477b095eb03d1be2d04a644eed3dc28"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001852530"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Odin-Plastic-Safety-Glasses/1001852530"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Odin Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822270
#     nanos: 212419000
#   }
#   modified_at {
#     seconds: 1599948343
#     nanos: 713094000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "0225a77c3de54a89bc8d01cc74518cc2"
#   input_id: "1001852530"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599948341
#     nanos: 941814000
#   }
#   modified_at {
#     seconds: 1599948341
#     nanos: 941814000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9577444
# input {
#   id: "1001852552"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001852552.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/2477b095eb03d1be2d04a644eed3dc28"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001852552"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Odin-Plastic-Anti-Fog-Safety-Glasses/1001852552"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Odin Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822271
#     nanos: 118321000
#   }
#   modified_at {
#     seconds: 1599948081
#     nanos: 244007000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "e61103c642f7473aacac150271f54852"
#   input_id: "1001852552"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599948079
#     nanos: 56015000
#   }
#   modified_at {
#     seconds: 1599948079
#     nanos: 56015000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9577444
# input {
#   id: "1001863850"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100186/1001863850.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/2477b095eb03d1be2d04a644eed3dc28"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001863850"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Skoll-Plastic-Safety-Glasses/1001863850"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Skoll Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "6c060629b21747359d9c2866c03e3175"
#   input_id: "1001863850"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336375000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336375000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9577444
# input {
#   id: "1001855010"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001855010.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/2477b095eb03d1be2d04a644eed3dc28"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001855010"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Skoll-Plastic-Anti-Fog-Safety-Glasses/1001855010"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Skoll Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "dde1135a5a794aca9472802ca1082966"
#   input_id: "1001855010"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336372000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336372000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95749974
# input {
#   id: "1001854702"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001854702.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/339ce26d90383bcb25485713a6a3bf09"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001854702"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Baldr-Plastic-Safety-Glasses/1001854702"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Baldr Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822268
#     nanos: 549315000
#   }
#   modified_at {
#     seconds: 1599946128
#     nanos: 716569000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "40f86461c0cc4b5ca688b01393764d67"
#   input_id: "1001854702"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599946126
#     nanos: 711922000
#   }
#   modified_at {
#     seconds: 1599946126
#     nanos: 711922000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95749974
# input {
#   id: "1001854724"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001854724.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/339ce26d90383bcb25485713a6a3bf09"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001854724"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Baldr-Plastic-Anti-Fog-Safety-Glasses/1001854724"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Baldr Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818333
#     nanos: 660450000
#   }
#   modified_at {
#     seconds: 1599927884
#     nanos: 242170000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "dc99724b5d0d4e62803f2c2c7bbab01b"
#   input_id: "1001854724"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927882
#     nanos: 523650000
#   }
#   modified_at {
#     seconds: 1599927882
#     nanos: 523650000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95712304
# input {
#   id: "1002438786"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/193027/193027064497.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/52a189839705d27fb00551a751faab6f"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1002438786"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/SAS-Safety-Plastic-Anti-Fog-Safety-Glasses-Flashlight-Included/1002438786"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "SAS Safety Plastic Anti-Fog Safety Glasses Flashlight Included"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818332
#     nanos: 423096000
#   }
#   modified_at {
#     seconds: 1599927863
#     nanos: 569850000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "da82bc693b1d46aaa09950e9b88c6ed0"
#   input_id: "1002438786"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927861
#     nanos: 848960000
#   }
#   modified_at {
#     seconds: 1599927861
#     nanos: 848960000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9567346
# input {
#   id: "1001740266"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100174/1001740266.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/648f1070d5a5b799f989a83a07f4d189"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001740266"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Odin-Plastic-Safety-Glasses/1001740266"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Odin Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822271
#     nanos: 118321000
#   }
#   modified_at {
#     seconds: 1599948081
#     nanos: 244007000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "bd46fbc20eb14473bab548d88d9d9d6d"
#   input_id: "1001740266"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599948079
#     nanos: 56030000
#   }
#   modified_at {
#     seconds: 1599948079
#     nanos: 56030000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9560495
# input {
#   id: "1001854110"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001854110.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/17a482d48222add4d734858be8fe512c"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001854110"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Loki-Plastic-Anti-Fog-Safety-Glasses/1001854110"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Loki Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "e0dec18c902f467da3f4ecbfb470fc6e"
#   input_id: "1001854110"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336379000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336379000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9560495
# input {
#   id: "1001854088"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001854088.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/17a482d48222add4d734858be8fe512c"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001854088"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Loki-Plastic-Safety-Glasses/1001854088"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Loki Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "e4e9ba9fe7d948539e7fdddd2e2d0926"
#   input_id: "1001854088"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336381000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336381000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95584744
# input {
#   id: "1001853936"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100185/1001853936.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/bef872381340f10eccdabe1a16662150"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001853936"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Kvasir-Plastic-Safety-Glasses/1001853936"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Kvasir Plastic Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_674"
#     }
#   }
#   created_at {
#     seconds: 1599818333
#     nanos: 660450000
#   }
#   modified_at {
#     seconds: 1599927884
#     nanos: 242170000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "baa276390b62497bb1bc79d4ca38f496"
#   input_id: "1001853936"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927882
#     nanos: 523652000
#   }
#   modified_at {
#     seconds: 1599927882
#     nanos: 523652000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95543015
# input {
#   id: "1001863150"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100186/1001863150.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/3dca897414c6afd5a0f4be962bc7bba6"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001863150"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Dagr-Plastic-Anti-Fog-Safety-Glasses/1001863150"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Dagr Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818335
#     nanos: 192557000
#   }
#   modified_at {
#     seconds: 1599927824
#     nanos: 329467000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "0b2a92561c4747c98e35bf1fd8421966"
#   input_id: "1001863150"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599927822
#     nanos: 336370000
#   }
#   modified_at {
#     seconds: 1599927822
#     nanos: 336370000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.95543015
# input {
#   id: "1001863654"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100186/1001863654.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/3dca897414c6afd5a0f4be962bc7bba6"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001863654"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
# ...
#         value {
#           string_value: "1001853526"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Skullerz-Dagr-Plastic-Anti-Fog-Safety-Glasses/1001853526"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Skullerz Dagr Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599822270
#     nanos: 212419000
#   }
#   modified_at {
#     seconds: 1599948343
#     nanos: 713094000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "bb6feacc2397408eae479edfef335cc4"
#   input_id: "1001853526"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599948341
#     nanos: 941794000
#   }
#   modified_at {
#     seconds: 1599948341
#     nanos: 941794000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.93923676
# input {
#   id: "1001821932"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100182/1001821932.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/503822df20bcdc56fb2e236689c4cb8f"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001821932"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Key-Largo-Polarized-Sunglasses-Tortoise-Frame-Amber-Lens/1001821932"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Key Largo Polarized Sunglasses Tortoise Frame Amber Lens"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819010
#     nanos: 639593000
#   }
#   modified_at {
#     seconds: 1599931310
#     nanos: 283567000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "4643ffd4ff0848d79d4e6475d5aeee87"
#   input_id: "1001821932"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599931307
#     nanos: 675517000
#   }
#   modified_at {
#     seconds: 1599931307
#     nanos: 675517000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.93918484
# input {
#   id: "1001849402"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100184/1001849402.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/3879d60ab9dbdc353ea7f4208f40bbb4"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001849402"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Tiki-Polarized-Sunglasses-Matte-Gray-Frame-Smoke-Lens/1001849402"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Tiki Polarized Sunglasses, Matte Gray Frame, Smoke Lens."
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819009
#     nanos: 960405000
#   }
#   modified_at {
#     seconds: 1599933750
#     nanos: 400124000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "4d66ea04f0e6450b8fdd0d9e4f90eb33"
#   input_id: "1001849402"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599933747
#     nanos: 244197000
#   }
#   modified_at {
#     seconds: 1599933747
#     nanos: 244197000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9391833
# input {
#   id: "1001849322"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100184/1001849322.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/0230ebbe860ab8aa5401f4432853f8d4"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001849322"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Helm-Polarized-Sunglasses-Matte-Black-Gunmetal-Frame-Yellow-Amber-Lens/1001849322"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Helm Polarized Sunglasses Matte Black Gunmetal Frame Yellow Amber Lens"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819010
#     nanos: 639593000
#   }
#   modified_at {
#     seconds: 1599931310
#     nanos: 283567000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "e77b97bfba294871a3c17b9c68485f0a"
#   input_id: "1001849322"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599931307
#     nanos: 675518000
#   }
#   modified_at {
#     seconds: 1599931307
#     nanos: 675518000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.93908817
# input {
#   id: "1001849024"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100184/1001849024.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/bff0322aa241efb6ae976a1382d74235"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001849024"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Buchanan-Polarized-Sunglasses-Crystal-Gunmetal-Frame-Smoke-Lens/1001849024"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Buchanan Polarized Sunglasses Crystal Gunmetal Frame Smoke Lens"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599815336
#     nanos: 355133000
#   }
#   modified_at {
#     seconds: 1599891581
#     nanos: 964603000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "ac5ede9eee094068a8e8fa753c1b23f3"
#   input_id: "1001849024"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599891575
#     nanos: 14363000
#   }
#   modified_at {
#     seconds: 1599891575
#     nanos: 14363000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.93902063
# input {
#   id: "1000039825"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/674326/674326289618.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/148a383ced41f45088e794da58aca8e7"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1000039825"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Safety Glasses, Goggles & Face Shields"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/DEWALT-Converter-Plastic-Anti-Fog-Safety-Glasses/1000039825"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "DEWALT Converter Plastic Anti-Fog Safety Glasses"
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599818330
#     nanos: 723532000
#   }
#   modified_at {
#     seconds: 1599926992
#     nanos: 439363000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "cda4e6e6a5524217bdbccba484f33bdf"
#   input_id: "1000039825"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599926990
#     nanos: 403802000
#   }
#   modified_at {
#     seconds: 1599926990
#     nanos: 403802000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9387353
# input {
#   id: "1001828758"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100182/1001828758.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/68d96a3cda538ade892dea750a049934"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001828758"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Sand-Bank-Polarized-Sunglasses-Matte-Black-Frame-Smoke-Lens/1001828758"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Sand Bank Polarized Sunglasses, Matte Black Frame, Smoke Lens."
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819010
#     nanos: 639593000
#   }
#   modified_at {
#     seconds: 1599931310
#     nanos: 283567000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "811d8e01296f45979c4f0fec51953b49"
#   input_id: "1001828758"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599931307
#     nanos: 675499000
#   }
#   modified_at {
#     seconds: 1599931307
#     nanos: 675499000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9387297
# input {
#   id: "1001849088"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100184/1001849088.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/2598949c9a6dd21fd7e2c8a0e9b5b959"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001849088"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Tailer-Polarized-Sunglasses-Brown-Frame-Amber-Lens/1001849088"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Tailer Polarized Sunglasses, Brown Frame, Amber Lens."
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819009
#     nanos: 960405000
#   }
#   modified_at {
#     seconds: 1599933750
#     nanos: 400124000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "9bcec97fbe3b4f799519a269b1c36980"
#   input_id: "1001849088"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599933747
#     nanos: 244174000
#   }
#   modified_at {
#     seconds: 1599933747
#     nanos: 244174000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# , score: 0.9387218
# input {
#   id: "1001848912"
#   data {
#     image {
#       url: "https://images.lowes.com/product/converted/100184/1001848912.jpg"
#       hosted {
#         prefix: "https://s3.amazonaws.com/clarifai-api/img3/prod"
#         suffix: "3617f25f9ee5463497e7abf350091b93/864fc293534ef216c1bcf2c3582f530c"
#         sizes: "orig"
#         sizes: "tiny"
#         sizes: "small"
#         sizes: "large"
#       }
#     }
#     metadata {
#       fields {
#         key: "cat_entry_id"
#         value {
#           string_value: "1001848912"
#         }
#       }
#       fields {
#         key: "catalog_name"
#         value {
#           string_value: "Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "catalog_path"
#         value {
#           string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#         }
#       }
#       fields {
#         key: "link_url"
#         value {
#           string_value: "https://www.lowes.com/pd/Flying-Fisherman-Razor-Polarized-Sunglasses-Dark-Tortoise-Frame-Amber-Lens/1001848912"
#         }
#       }
#       fields {
#         key: "product_name"
#         value {
#           string_value: "Flying Fisherman Razor Polarized Sunglasses Dark Tortoise Frame, Amber Lens."
#         }
#       }
#     }
#     clusters {
#       id: "518_470"
#     }
#   }
#   created_at {
#     seconds: 1599819010
#     nanos: 639593000
#   }
#   modified_at {
#     seconds: 1599931310
#     nanos: 283567000
#   }
#   status {
#     code: INPUT_DOWNLOAD_SUCCESS
#     description: "Download complete"
#   }
# }
# annotation {
#   id: "5e9de591637c46b69844c581cf825dcc"
#   input_id: "1001848912"
#   data {
#   }
#   status {
#     code: ANNOTATION_SUCCESS
#     description: "Annotation success"
#   }
#   created_at {
#     seconds: 1599931307
#     nanos: 675528000
#   }
#   modified_at {
#     seconds: 1599931307
#     nanos: 675528000
#   }
#   model_version_id: "bb186755eda04f9cbb6fe32e816be104"
# }
# ]

# %% [markdown]
# ### The metadata added to an image in Portal looks like as follows
#
# ![](./images/visual_search_metadata.png)

# %% [markdown]
# ### Let's look at one returned response to what is actually being returned. We will look at the top returned result.

# %%
metadata = search_response.hits[0].input.data.metadata.fields

print('score :',search_response.hits[0].score,'\n\n')
print('Now printing metadata \n\n')

for k, v in metadata.items():
    print(k,v)
# Out:
# score : 0.9642383456230164
#
#
# Now printing metadata
#
#
# catalog_path string_value: "Tools$Safety & Workwear$Sunglasses & Glasses"
#
# catalog_name string_value: "Sunglasses & Glasses"
#
# cat_entry_id string_value: "1002701328"
#
# link_url string_value: "https://www.lowes.com/pd/Magnifeye-Magnifeye-Retro-Black-1-25/1002701328"
#
# product_name string_value: "Magnifeye Magnifeye Retro Black 1.25"

# %% [markdown]
# ### In the above response we can see there being URL returned which we can use to redirect a user to a product that matches what they are looking for baed on thier similarity

# %% [markdown]
# <a id='apparel-detection'></a>
# ## Apparel Detection
#
# **Using Clarifai to answer retail apparel use-cases:**
#
# You can use Clarifai's [Apparel Detection Model](https://www.clarifai.com/models/apparel-detection) to answer real-world fashion industry related use cases. The Model looks at inputs(iamges/videos) and in each input detects different clothing/accessory items by putting bounding boxes around them.
#
# This is what the Apparel model's output would look like ![apparel_detect_image](./images/apparel_2.png)
#
#
# You can make a prediction to it, the same way you would make prediction to a custom model. The API endpoint for custom model predictions works by you giving it a model id. In case of a custom model the model is is the name you give it. However, you could provide that endpoint the model id for any other model (General Model. Face Model, Racial appearence model and it will work that way as well. So we are just going to give that endpoint the model id for the Apparel detection model as well as an image to predict on.
#
# **The model id for the Apparel Detection model is *72c523807f93e18b431676fb9a58e6ad***
#
# We will be running a prediction on the following image. The Apparel Detection model will tell us what items of apparel are in there as well as the bounding boxes where they are
#
# ![appare-detect-test](https://images.pexels.com/photos/1075776/pexels-photo-1075776.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=750&w=1260)

# %%
# Setting up an API connection with an API key
# The API key needs to be from the application where the model was created. 

metadata = (('authorization', 'Key YOUR_API_KEY'),)

apparel_response = stub.PostModelOutputs(
    service_pb2.PostModelOutputsRequest(
        model_id="72c523807f93e18b431676fb9a58e6ad", #model id for apparel detection model 
#         version_id="{YOUR_MODEL_VERSION_ID}",  # This is optional. Defaults to the latest model version.
        inputs=[
            resources_pb2.Input(
                data=resources_pb2.Data(
                    image=resources_pb2.Image(
                        url="https://images.pexels.com/photos/1075776/pexels-photo-1075776.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=750&w=1260"
                    )
                )
            )
        ]
    ),
    metadata=metadata
)
if apparel_response.status.code != status_code_pb2.SUCCESS:
    raise Exception("Post model outputs failed, status: " + apparel_response.status.description)
else:
    print('prediction made successfully')
# Out:
# prediction made successfully

# %%
apparel_regions = apparel_response.outputs[0].data.regions
print('There detected items of clothing/accessories are: ', len(apparel_regions),'\n\n')
# Out:
# There detected items of clothing/accessories are:  13

# %%
apparel_regions
# Out:
# [id: "6rj0elzvkuft"
# region_info {
#   bounding_box {
#     top_row: 0.7731218
#     left_col: 0.23859031
#     bottom_row: 0.86608905
#     right_col: 0.3198795
#   }
# }
# data {
#   concepts {
#     id: "ai_6ZGj27W6"
#     name: "shoes"
#     value: 0.9998909
#     app_id: "main"
#   }
# }
# value: 0.9998909
# , id: "lrj9q3oh4ama"
# region_info {
#   bounding_box {
#     top_row: 0.35927078
#     left_col: 0.22859108
#     bottom_row: 0.56041604
#     right_col: 0.5675377
#   }
# }
# data {
#   concepts {
#     id: "ai_nrTL5JlX"
#     name: "top"
#     value: 0.9998543
#     app_id: "main"
#   }
# }
# value: 0.9998543
# , id: "7hoaeihh3bnu"
# region_info {
#   bounding_box {
#     top_row: 0.80863893
#     left_col: 0.5229257
#     bottom_row: 0.91169196
#     right_col: 0.6447445
#   }
# }
# data {
#   concepts {
#     id: "ai_6ZGj27W6"
#     name: "shoes"
#     value: 0.99953973
#     app_id: "main"
#   }
# }
# value: 0.99953973
# , id: "g2v1x2g3ebdr"
# region_info {
#   bounding_box {
#     top_row: 0.47035095
#     left_col: 0.28079987
#     bottom_row: 0.8009345
#     right_col: 0.637596
#   }
# }
# data {
#   concepts {
#     id: "ai_PMKkLK0K"
#     name: "pants"
#     value: 0.99935716
#     app_id: "main"
#   }
# }
# value: 0.99935716
# , id: "px7kdw31vn4p"
# region_info {
#   bounding_box {
#     top_row: 0.5579039
#     left_col: 0.5728075
#     bottom_row: 0.58921874
#     right_col: 0.6122371
#   }
# }
# data {
#   concepts {
#     id: "ai_ckdxd4DP"
#     name: "bracelet"
#     value: 0.99107575
#     app_id: "main"
#   }
# }
# value: 0.99107575
# , id: "831szvpjgfjq"
# region_info {
#   bounding_box {
#     top_row: 0.5546343
#     left_col: 0.2128615
#     bottom_row: 0.5702575
#     right_col: 0.24901801
#   }
# }
# data {
#   concepts {
#     id: "ai_ckdxd4DP"
#     name: "bracelet"
#     value: 0.94982165
#     app_id: "main"
#   }
# }
# value: 0.94982165
# , id: "t6ixvz8cmp3o"
# region_info {
#   bounding_box {
#     top_row: 0.767774
#     left_col: 0.2532234
#     bottom_row: 0.836142
#     right_col: 0.31639898
#   }
# }
# data {
#   concepts {
#     id: "ai_vGLGpcKl"
#     name: "socks"
#     value: 0.946608
#     app_id: "main"
#   }
# }
# value: 0.946608
# , id: "318m0l07in66"
# region_info {
#   bounding_box {
#     top_row: 0.5194488
#     left_col: 0.5236351
#     bottom_row: 0.5446718
#     right_col: 0.5749008
#   }
# }
# data {
#   concepts {
#     id: "ai_ckdxd4DP"
#     name: "bracelet"
#     value: 0.9118653
#     app_id: "main"
#   }
# }
# value: 0.9118653
# , id: "vpztr0fkgkny"
# region_info {
#   bounding_box {
#     top_row: 0.76593983
#     left_col: 0.2716126
#     bottom_row: 0.7969306
#     right_col: 0.32355195
#   }
# }
# data {
#   concepts {
#     id: "ai_vGLGpcKl"
#     name: "socks"
#     value: 0.8900828
#     app_id: "main"
#   }
# }
# value: 0.8900828
# , id: "838zkcvcraps"
# region_info {
#   bounding_box {
#     top_row: 0.5973529
#     left_col: 0.61183184
#     bottom_row: 0.6157903
#     right_col: 0.6544722
#   }
# }
# data {
#   concepts {
#     id: "ai_ckdxd4DP"
#     name: "bracelet"
#     value: 0.77278256
#     app_id: "main"
#   }
# }
# value: 0.77278256
# , id: "wrs8v8jmy2jc"
# region_info {
#   bounding_box {
#     top_row: 0.5876986
#     left_col: 0.2975998
#     bottom_row: 0.63191545
#     right_col: 0.35379657
#   }
# }
# data {
#   concepts {
#     id: "ai_vGLGpcKl"
#     name: "socks"
#     value: 0.42799613
#     app_id: "main"
#   }
# }
# value: 0.42799613
# , id: "gryhffussg5j"
# region_info {
#   bounding_box {
#     top_row: 0.31820798
#     left_col: 0.43235633
#     bottom_row: 0.3482754
#     right_col: 0.51159406
#   }
# }
# data {
#   concepts {
#     id: "ai_74v5zNzS"
#     name: "sunglasses"
#     value: 0.42660078
#     app_id: "main"
#   }
# }
# value: 0.42660078
# , id: "zptux6omygok"
# region_info {
#   bounding_box {
#     top_row: 0.79873306
#     left_col: 0.5368541
#     bottom_row: 0.8878955
#     right_col: 0.6328477
#   }
# }
# data {
#   concepts {
#     id: "ai_vGLGpcKl"
#     name: "socks"
#     value: 0.30658856
#     app_id: "main"
#   }
# }
# value: 0.30658856
# ]

# %% [markdown]
# **In the above output we can see the number of items that were detected in the image. These items are not only returned with where they are but also where they are in the image which we can use to see where in the image that item was detected. Let's take a look at one items that was detected.**

# %%
apparel_regions[np.random.randint(0,len(apparel_regions))]
# Out:
# id: "px7kdw31vn4p"
# region_info {
#   bounding_box {
#     top_row: 0.5579039
#     left_col: 0.5728075
#     bottom_row: 0.58921874
#     right_col: 0.6122371
#   }
# }
# data {
#   concepts {
#     id: "ai_ckdxd4DP"
#     name: "bracelet"
#     value: 0.99107575
#     app_id: "main"
#   }
# }
# value: 0.99107575

# %% [markdown]
# **Let's take a look at what that image would look like in our Portal when we predict on this image.**
#
# ![apparel-demo-final](./images/apparel_demo.png)
